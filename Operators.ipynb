# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshi082004/ml-project/blob/dev/Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Operators in python
# 1.Arithmatic Operators
# 2.Assignment Operators
# 3.Comparison Operators
# 4.Logical Operators
# 5.Identity Operators
# 6.Membership Operators

# %% [markdown]
# 1.Arithmetic Operator

# %%
num_1 = 28
num_2 = 7
#addition
sum = num_1+num_2
print("sum = ",sum)
#subtraction
diff = num_1-num_2
print("difference = ",diff)
#multiplecation
product = num_1*num_2
print("product = ",product)
#division
division = num_1/num_2
print("division = ",division)
#modulas
modulas = num_1%num_2
print("modulas = ",modulas)
#exponent
exp = num_1**num_2
print("exponent = ",exp)
# Out:
# sum =  35
# difference =  21
# product =  196
# division =  4.0
# modulas =  0
# exponent =  13492928512

# %% [markdown]
# 2.Assignment Operator

# %%
a = 5
print(a)
a += 5
print(a)
a -= 5
print(a)
a *= 5
print(a)
a /= 5
print(a)
a %= 5
print(a)
a **= 5
print(a)
# Out:
# 5
# 10
# 5
# 25
# 5.0
# 0.0
# 0.0

# %% [markdown]
# 3.Comparision Operators

# %%
a = 5
b= 10
print(a == b)# equal to
print(a != b)# not equal to
print(a > b)# greater than
print(a < b)# less than
print(a >= b)# greater than or equal to
print(a <= b)# less than or equal to
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# 4.Logical operator
# and
# or
# not

# %%
a = 10
print(a > 20 and a > 5)# check both condition
print(a > 20 or a > 5)# check only one condition
print(not(a < 20 and a > 5))# check both condition and return opposite ans
# Out:
# False
# True
# False

# %% [markdown]
# 5.Identity Operator
# is
# is not

# %%
x = 5
y = 5
print (x is y)
# Out:
# True

# %%
x = 5
y = 5
print (x is not y)
# Out:
# False

# %%
x = 5
y = 10
print (x is  not y)
# Out:
# True

# %% [markdown]
# 6.Membership operator
# in
# not in

# %%
a = 5
b = 10
c = [1,2,3,4,5]
print(a in c)
print(b in c)
# Out:
# True
# False

# %%
a = 5
b = 10
c = [1,2,3,4,5]
print(a not in c)
print(b not in c)
# Out:
# False
# True
